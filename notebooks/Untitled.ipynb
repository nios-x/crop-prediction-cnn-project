# %% [markdown]
# # PROBLEM STATEMENT 1 - [Type: Deep Learning + Web App]\n\n**Goal:** Build a crop disease detection web app for farmers. A user uploads a photo of a leaf; a trained model predicts the most likely disease and returns a short remedy tip.\n\nThis notebook documents a reproducible pipeline: dataset acquisition, model training (transfer learning with MobileNet/ResNet), exporting the model for use in the Next.js app, and an example inference snippet and remedies lookup.

# %% [markdown]
# ## Scope & Requirements\n\n- Classify 3–5 common leaf diseases (or more) using PlantVillage or a similar dataset.\n- Provide per-class remedy tips stored in a small JSON lookup.\n- Expose a minimal web upload page and API endpoint that returns: top-1 (or top-3) predictions and remedy text, plus confidence scores.\n- Optionally persist a simple history of uploads and predictions (in a JSON file or lightweight DB).

# %% [markdown]
# ## Environment setup (Python)\n\nUse a Python 3.8+ environment. Typical packages used below: TensorFlow (or PyTorch), tensorflow_datasets (optional), Pillow, scikit-learn.\n\nRun these in your shell before executing the cells:
